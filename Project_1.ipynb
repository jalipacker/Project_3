# %% [markdown]
# # Project 1

# %% [markdown]
# ## Steps 1 to 4

# %% [markdown]
# Import dataset on COVID-19 daily count. Sourced from NYC OpenData: https://data.cityofnewyork.us/Health/COVID-19-Daily-Counts-of-Cases-Hospitalizations-an/rc75-m7u3/about_data

# %%
import pandas as pd

# %% [markdown]
# ## Step 5

# %%
#read in the covid dataset using pandas and view first five rows
covid = pd.read_csv('COVID-19_Daily_Counts_of_Cases__Hospitalizations__and_Deaths_20241107.csv')
covid.head()
# Out:
#   date_of_interest  CASE_COUNT  PROBABLE_CASE_COUNT  HOSPITALIZED_COUNT  \
# 0       02/29/2020           1                    0                   1
# 1       03/01/2020           0                    0                   1
# 2       03/02/2020           0                    0                   2
# 3       03/03/2020           1                    0                   7
# 4       03/04/2020           5                    0                   2
#
#    DEATH_COUNT  CASE_COUNT_7DAY_AVG  ALL_CASE_COUNT_7DAY_AVG  \
# 0            0                    0                        0
# 1            0                    0                        0
# 2            0                    0                        0
# 3            0                    0                        0
# 4            0                    0                        0
#
#    HOSP_COUNT_7DAY_AVG  DEATH_COUNT_7DAY_AVG  BX_CASE_COUNT  ...  \
# 0                    0                     0              0  ...
# ...

# %%
#inspect dataset
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 55 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date_of_interest                 1704 non-null   object
#  1   CASE_COUNT                       1704 non-null   int64
#  2   PROBABLE_CASE_COUNT              1704 non-null   int64
#  3   HOSPITALIZED_COUNT               1704 non-null   int64
#  4   DEATH_COUNT                      1704 non-null   int64
#  5   CASE_COUNT_7DAY_AVG              1704 non-null   int64
#  6   ALL_CASE_COUNT_7DAY_AVG          1704 non-null   int64
#  7   HOSP_COUNT_7DAY_AVG              1704 non-null   int64
#  8   DEATH_COUNT_7DAY_AVG             1704 non-null   int64
#  9   BX_CASE_COUNT                    1704 non-null   int64
#  10  BX_PROBABLE_CASE_COUNT           1704 non-null   int64
#  11  BX_HOSPITALIZED_COUNT            1704 non-null   int64
# ...

# %%
#inspect 'CASE_COUNT' column data
covid['CASE_COUNT']
# Out:
# 0         1
# 1         0
# 2         0
# 3         1
# 4         5
#        ...
# 1699    110
# 1700     99
# 1701     62
# 1702     83
# 1703     79
# Name: CASE_COUNT, Length: 1704, dtype: int64

# %%
#inspect counts of values for 'CASE_COUNT' column
covid['CASE_COUNT'].value_counts()
# Out:
# CASE_COUNT
# 220     7
# 283     7
# 118     6
# 126     5
# 308     5
#        ..
# 1011    1
# 610     1
# 1110    1
# 884     1
# 83      1
# Name: count, Length: 1237, dtype: int64

# %%
#calculate mean, median, and mode of 'CASE_COUNT' column
mean = covid['CASE_COUNT'].mean()
median = covid['CASE_COUNT'].median()
mode = covid['CASE_COUNT'].mode()

# %%
#print mean, median, and mode
print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
# Out:
# Mean: 1746.9049295774648
# Median: 773.5
# Mode: 0    220
# 1    283
# Name: CASE_COUNT, dtype: int64

# %% [markdown]
# ## Step 6

# %%
#import csv without using pandas
import csv

with open('COVID-19_Daily_Counts_of_Cases__Hospitalizations__and_Deaths_20241107.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row)
        break
# Out:
# {'date_of_interest': '02/29/2020', 'CASE_COUNT': '1', 'PROBABLE_CASE_COUNT': '0', 'HOSPITALIZED_COUNT': '1', 'DEATH_COUNT': '0', 'CASE_COUNT_7DAY_AVG': '0', 'ALL_CASE_COUNT_7DAY_AVG': '0', 'HOSP_COUNT_7DAY_AVG': '0', 'DEATH_COUNT_7DAY_AVG': '0', 'BX_CASE_COUNT': '0', 'BX_PROBABLE_CASE_COUNT': '0', 'BX_HOSPITALIZED_COUNT': '0', 'BX_DEATH_COUNT': '0', 'BX_CASE_COUNT_7DAY_AVG': '0', 'BX_PROBABLE_CASE_COUNT_7DAY_AVG': '0', 'BX_ALL_CASE_COUNT_7DAY_AVG': '0', 'BX_HOSPITALIZED_COUNT_7DAY_AVG': '0', 'BX_DEATH_COUNT_7DAY_AVG': '0', 'BK_CASE_COUNT': '0', 'BK_PROBABLE_CASE_COUNT': '0', 'BK_HOSPITALIZED_COUNT': '1', 'BK_DEATH_COUNT': '0', 'BK_CASE_COUNT_7DAY_AVG': '0', 'BK_PROBABLE_CASE_COUNT_7DAY_AVG': '0', 'BK_ALL_CASE_COUNT_7DAY_AVG': '0', 'BK_HOSPITALIZED_COUNT_7DAY_AVG': '0', 'BK_DEATH_COUNT_7DAY_AVG': '0', 'MN_CASE_COUNT': '1', 'MN_PROBABLE_CASE_COUNT': '0', 'MN_HOSPITALIZED_COUNT': '0', 'MN_DEATH_COUNT': '0', 'MN_CASE_COUNT_7DAY_AVG': '0', 'MN_PROBABLE_CASE_COUNT_7DAY_AVG': '0', 'MN_ALL_C
# ...

# %%
covid = []
with open('COVID-19_Daily_Counts_of_Cases__Hospitalizations__and_Deaths_20241107.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        covid.append(row)

covid[:3]
# Out:
# [{'date_of_interest': '02/29/2020',
#   'CASE_COUNT': '1',
#   'PROBABLE_CASE_COUNT': '0',
#   'HOSPITALIZED_COUNT': '1',
#   'DEATH_COUNT': '0',
#   'CASE_COUNT_7DAY_AVG': '0',
#   'ALL_CASE_COUNT_7DAY_AVG': '0',
#   'HOSP_COUNT_7DAY_AVG': '0',
#   'DEATH_COUNT_7DAY_AVG': '0',
#   'BX_CASE_COUNT': '0',
#   'BX_PROBABLE_CASE_COUNT': '0',
#   'BX_HOSPITALIZED_COUNT': '0',
#   'BX_DEATH_COUNT': '0',
#   'BX_CASE_COUNT_7DAY_AVG': '0',
#   'BX_PROBABLE_CASE_COUNT_7DAY_AVG': '0',
#   'BX_ALL_CASE_COUNT_7DAY_AVG': '0',
#   'BX_HOSPITALIZED_COUNT_7DAY_AVG': '0',
#   'BX_DEATH_COUNT_7DAY_AVG': '0',
#   'BK_CASE_COUNT': '0',
#   'BK_PROBABLE_CASE_COUNT': '0',
#   'BK_HOSPITALIZED_COUNT': '1',
#   'BK_DEATH_COUNT': '0',
#   'BK_CASE_COUNT_7DAY_AVG': '0',
#   'BK_PROBABLE_CASE_COUNT_7DAY_AVG': '0',
#   'BK_ALL_CASE_COUNT_7DAY_AVG': '0',
#   'BK_HOSPITALIZED_COUNT_7DAY_AVG': '0',
#   'BK_DEATH_COUNT_7DAY_AVG': '0',
#   'MN_CASE_COUNT': '1',
#   'MN_PROBABLE_CASE_COUNT': '0',
# ...

# %%
cases = []
for row in covid: 
    cases.append(float(row['CASE_COUNT']))

# %% [markdown]
# #### Calculate the mean, median, and mode. Code sourced from: https://www.geeksforgeeks.org/finding-mean-median-mode-in-python-without-libraries/

# %%
# calculate the mean
total_cases = sum(cases)
count = len(cases)
mean_cases = total_cases / count
print("Mean:", mean_cases)
# Out:
# Mean: 1746.9049295774648

# %%
# calculate the median - first sort the list of numbers
n = len(cases) 
cases.sort() 
cases
# Out:
# [0.0,
#  0.0,
#  1.0,
#  1.0,
#  3.0,
#  5.0,
#  7.0,
#  8.0,
#  21.0,
#  56.0,
#  57.0,
#  62.0,
#  69.0,
#  71.0,
#  75.0,
#  79.0,
#  79.0,
#  82.0,
#  83.0,
#  88.0,
#  88.0,
#  88.0,
#  89.0,
#  90.0,
#  90.0,
#  91.0,
#  92.0,
#  93.0,
#  94.0,
#  94.0,
#  95.0,
#  96.0,
#  96.0,
#  97.0,
#  97.0,
#  98.0,
#  98.0,
#  99.0,
#  99.0,
#  99.0,
#  103.0,
#  104.0,
#  107.0,
#  108.0,
#  108.0,
#  109.0,
#  109.0,
#  110.0,
#  110.0,
#  111.0,
#  111.0,
#  111.0,
#  111.0,
#  112.0,
#  113.0,
#  114.0,
#  114.0,
#  117.0,
#  117.0,
#  118.0,
#  118.0,
#  118.0,
#  118.0,
#  118.0,
#  118.0,
#  120.0,
#  120.0,
#  121.0,
#  121.0,
#  121.0,
#  122.0,
#  122.0,
#  124.0,
#  126.0,
#  126.0,
#  126.0,
#  126.0,
#  126.0,
#  128.0,
#  128.0,
#  128.0,
#  129.0,
#  130.0,
#  130.0,
#  131.0,
#  132.0,
#  133.0,
#  133.0,
#  133.0,
#  134.0,
#  134.0,
#  135.0,
#  135.0,
#  135.0,
#  135.0,
#  136.0,
#  136.0,
#  136.0,
#  136.0,
#  137.0,
#  137.0,
#  137.0,
#  138.0,
#  138.0,
# ...

# %%
# calculate the median - check if the middle number is even or odd and proceed accordingly 
if n % 2 == 0: 
    median1 = cases[n//2] 
    median2 = cases[n//2 - 1] 
    median = (median1 + median2)/2
else: 
    median = cases[n//2] 
print("Median is: " + str(median))
# Out:
# Median is: 773.5

# %%
# calculate the mode, code sourced from chatGPT: https://chatgpt.com/share/67393147-9d7c-8008-aec9-6e705d8f48e5

frequency_dict = {}
for value in cases:
    if value in frequency_dict:
        frequency_dict[value] += 1
    else:
        frequency_dict[value] = 1

# %%
# find values with max frequency 
max_frequency = max(frequency_dict.values())

# %%
# use multimode as we know from Step 3 that there are two modes for this data
modes = [key for key, count in frequency_dict.items() if count == max_frequency]

# %%
print(f"The mode(s) is/are: {modes}")
# Out:
# The mode(s) is/are: [220.0, 283.0]

# %% [markdown]
# ## Data visualization

# %%
#read in the covid dataset again using pandas and view first five rows
covid = pd.read_csv('COVID-19_Daily_Counts_of_Cases__Hospitalizations__and_Deaths_20241107.csv')
covid.head()
# Out:
#   date_of_interest  CASE_COUNT  PROBABLE_CASE_COUNT  HOSPITALIZED_COUNT  \
# 0       02/29/2020           1                    0                   1
# 1       03/01/2020           0                    0                   1
# 2       03/02/2020           0                    0                   2
# 3       03/03/2020           1                    0                   7
# 4       03/04/2020           5                    0                   2
#
#    DEATH_COUNT  CASE_COUNT_7DAY_AVG  ALL_CASE_COUNT_7DAY_AVG  \
# 0            0                    0                        0
# 1            0                    0                        0
# 2            0                    0                        0
# 3            0                    0                        0
# 4            0                    0                        0
#
#    HOSP_COUNT_7DAY_AVG  DEATH_COUNT_7DAY_AVG  BX_CASE_COUNT  ...  \
# 0                    0                     0              0  ...
# ...

# %%
# convert date to datetime and extract year from the date - code for datetime sourced from chatGPT
covid['date_of_interest'] = pd.to_datetime(covid['date_of_interest'])
covid['year'] = covid['date_of_interest'].dt.year

# %%
# calculate the average case count by year
average_case_count_by_year = covid.groupby('year')['CASE_COUNT'].mean()

# %%
# Generate a data visualization for the average case count by year
data_viz = "Average Daily COVID-19 Case Count by Year\n" 
for year, avg_count in average_case_count_by_year.items():
    stars = '*' * round(avg_count / 100)  # Each '*' represents approximately 100 cases
    data_viz += f"{year}: {stars} ({avg_count:.0f} cases)\n"

data_viz += "=" * 50 + "\nNote: Each '*' represents approximately 100 cases."
print(data_viz)
# Out:
# Average Daily COVID-19 Case Count by Year
# 2020: ************* (1308 cases)
# 2021: ***************************** (2899 cases)
# 2022: ******************************** (3217 cases)
# 2023: ****** (611 cases)
# 2024: **** (396 cases)
# ...
# Note: Each '*' represents approximately 100 cases.
